# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_table('rt_leavetimes_2017_I_DB_1000.txt',sep=';')

# %%
df.head(15)
# Out:
#    datasource        dayofservice   tripid  progrnumber  stoppointid  \
# 0          DB  27-MAR-17 00:00:00  4529349            5         4384
# 1          DB  27-MAR-17 00:00:00  4529349           10          523
# 2          DB  27-MAR-17 00:00:00  4529349           15         4382
# 3          DB  27-MAR-17 00:00:00  4529349           20         1223
# 4          DB  27-MAR-17 00:00:00  4529349           25         1228
# 5          DB  27-MAR-17 00:00:00  4529349           30         1231
# 6          DB  27-MAR-17 00:00:00  4529349           35         5174
# 7          DB  27-MAR-17 00:00:00  4534742           43           79
# 8          DB  27-MAR-17 00:00:00  4534742           48          819
# 9          DB  27-MAR-17 00:00:00  4519838            5         7017
# 10         DB  27-MAR-17 00:00:00  4519838           10         6112
# 11         DB  27-MAR-17 00:00:00  4519838           15         1860
# 12         DB  27-MAR-17 00:00:00  4519838           20         1864
# ...

# %%
df.shape
# Out:
# (999, 18)

# %%
df.dtypes
# Out:
# datasource          object
# dayofservice        object
# tripid               int64
# progrnumber          int64
# stoppointid          int64
# plannedtime_arr      int64
# plannedtime_dep      int64
# actualtime_arr       int64
# actualtime_dep       int64
# vehicleid            int64
# passengers         float64
# passengersin       float64
# passengersout      float64
# distance           float64
# suppressed         float64
# justificationid    float64
# lastupdate          object
# note               float64
# dtype: object

# %%
df1 = pd.read_table('rt_trips_2017_I_DB_1000.txt',sep=';')

# %%
df1.head(15)
# Out:
#    datasource        dayofservice   tripid lineid  routeid  direction  \
# 0          DB  24-FEB-17 00:00:00  4391739    140   140_19          1
# 1          DB  24-FEB-17 00:00:00  4388762    140   140_19          1
# 2          DB  24-FEB-17 00:00:00  4381744      4     4_12          2
# 3          DB  24-FEB-17 00:00:00  4388860    84A    84A_1          1
# 4          DB  24-FEB-17 00:00:00  4388883    39A   39A_40          1
# 5          DB  24-FEB-17 00:00:00  4388888    39A   39A_43          2
# 6          DB  24-FEB-17 00:00:00  4389028     39    39_21          2
# 7          DB  24-FEB-17 00:00:00  4379972     27    27_17          2
# 8          DB  24-FEB-17 00:00:00  4380017     41     41_7          2
# 9          DB  24-FEB-17 00:00:00  4380023    41C   41C_79          2
# 10         DB  24-FEB-17 00:00:00  4380062    33B   33B_56          1
# 11         DB  24-FEB-17 00:00:00  4385490     13    13_72          2
# ...

# %%
df2 = pd.read_table('stops.txt',sep=',')

# %%
df2.head(15)
# Out:
#      stop_lat  zone_id  stop_lon       stop_id  \
# 0   53.248044      NaN -6.123154  8250DB007556
# 1   53.228471      NaN -6.185499  8250DB004086
# 2   53.390386      NaN -6.278349  8220DB000131
# 3   53.289040      NaN -6.339486  8230DB002554
# 4   53.362907      NaN -6.302642  8220DB001806
# 5   53.331684      NaN -6.294558  8220DB003952
# 6   53.325650      NaN -6.207334  8220DB000378
# 7   53.298028      NaN -6.211417  8250DB002080
# 8   53.303330      NaN -6.209575  8250DB002083
# 9   53.343179      NaN -6.315381  8220DB007435
# 10  53.305527      NaN -6.211599  8250DB002084
# 11  53.379868      NaN -6.280066  8220DB007430
# 12  53.379729      NaN -6.279185  8220DB007431
# 13  53.338613      NaN -6.223055  8220DB000371
# 14  53.335423      NaN -6.219538  8220DB000372
#
#                                             stop_name  location_type
# 0                                            Abberley              0
# ...
